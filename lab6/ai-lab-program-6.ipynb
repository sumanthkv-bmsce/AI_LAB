# %% [markdown]
# # Entailment Program
# ### Using Knowledge Base

# %% [markdown]
# BMS College of Engineering - Dr Kavitha Sooda <br />
# BMS College of Engineering - Prof Sowmya V <br />
# BMS College of Engineering - Prof G R Asha  <br />
# ##### Class 5C

# %% [markdown]
# ## Objective
# - Build a knowledge base
# - Pass a statement/query and check if the knowledge base entails with the statement

# %% [markdown]
# ![](https://edukite.org/wp-content/uploads/2018/05/97-Knowledge-Based-AI-Cognitive-Systems.jpg)

# %% [markdown]
# # Example
# Here is a situation with 3 variables. Imagine you are a bot put in an environment with these variables
# ### 3 variables
# - Sunny: True, Rainy: False
# - Have Umbrella: True, Dont have Umbrella: False
# - Wet: True, Not Wet: False

# %% [markdown]
# ![](https://ph.toluna.com//dpolls_images/2018/08/11/4af73596-4bae-4bd9-b0e1-49ffc4b7712d.jpg)

# %% [markdown]
# ## Acquire first piece of knowledge
# As there are 3 variables, all combinations of true and false can be put into a combinations array. x[0] represents sunny, x[1] represents umbrella and so on...
# ```
# combinations=[(True,True, True),(True,True,False),
#               (True,False,True),(True,False, False),
#               (False,True, True),(False,True, False),
#               (False,False,True),(False,False,False)]
#
#
# ```

# %% [markdown]
# ## The bot learns that
# - If it is raining and you dont have an umberella then you are wet
# ![](https://cdn4.iconfinder.com/data/icons/warning-signs-4/64/warning_sign_alert_danger_rain_weather-512.png)

# %% [markdown]
# ```
# # Rule to tell
# # (not sunny ^ not_carrying_umberella) => wet
#
#
# # We will write this rule as a function to tell the knowledge base
#
# r1 = lambda x: not (not x[0] and not x[1]) or x[2] # Convert implies to CNF
# ```

# %% [markdown]
# ## Your bot gets stopped with a query
# - You are dry
# ![](https://comps.canstockphoto.com/keep-dry-no-water-sign-illustration_csp73478527.jpg)

# %% [markdown]
# ```
# # Query
# # Dry
#
# # Query as a function to ask Knowledge base
#
# q = lambda x: not x[2]
# ```

# %% [markdown]
# ## Bot is told
# - You have and umbrella
#
# ```
# r2 = lambda x: x[1]
# ```

# %% [markdown]
# ## Bot gets stopped for another question
# - Your have an umbrella therefore you wont get wet
#
# ```
# # have_umbrella => not wet
#
# q = lambda x: not x[1] or x[2]
# ```

# %% [markdown]
# # Your task is
# - Create Knowledge base which is an array of rules(functions)
# - Ask queries to see if KB entails query for all possible combinations of variables

# %%
def processsing_kb_rule(kb_rule):
    kb_rule = kb_rule.replace('~', ' not ')
    kb_rule = kb_rule.replace('^', ' and ')
    kb_rule = kb_rule.replace('v', ' or ')
    return kb_rule

def formatting_kb_rule(kb_rule, P, Q, R):
    P, Q, R = str(P), str(Q), str(R)
    kb_rule = kb_rule.replace('P', P)
    kb_rule = kb_rule.replace('Q', Q)
    kb_rule = kb_rule.replace('R', R)
    return kb_rule

# %%
kb = [
        (False, False, False),
        (False, False, True),
        (False, True, False),
        (False, True, True),
        (True, False, False),
        (True, False, True),
        (True, True, False),
        (True, True, True)
    ]

# %%
def to_check_entailment(kb_rule, query):
    
    is_entails = True
    
    kb_rule = processsing_kb_rule(kb_rule)
    
    for i, j, k in kb:
        formatted_rule = formatting_kb_rule(kb_rule, i, j, k) 
        print(f'To Evaluate: {formatted_rule}')
        KB = eval(formatted_rule)
        
        if query=='R':
            act_query = k
        elif query=='P':
            act_query = i
        else:
            act_query = j
        
        print(f'Knowledge Base: {KB}      Query: {act_query}',end="\n\n")
        
        if KB and not (KB and act_query):
            is_entails = False
            break

    if is_entails:
        print('Knowledge Base entailing the query')
    else:
        print("Knowledge Base doesn't entailing the query")

# %%
kb_rule = input('Enter the KB_rule: ')
# (~Qv~PvR)^(~Q^P)^Q
query = input('Enter the query: ')
# R

to_check_entailment(kb_rule, query)
# Out:
# Enter the KB_rule: (~Qv~PvR)^(~Q^P)^Q
# Enter the query: R
# To Evaluate: ( not False or  not False or False) and ( not False and False) and False
# Knowledge Base: False      Query: False
#
# To Evaluate: ( not False or  not False or True) and ( not False and False) and False
# Knowledge Base: False      Query: True
#
# To Evaluate: ( not True or  not False or False) and ( not True and False) and True
# Knowledge Base: False      Query: False
#
# To Evaluate: ( not True or  not False or True) and ( not True and False) and True
# Knowledge Base: False      Query: True
#
# To Evaluate: ( not False or  not True or False) and ( not False and True) and False
# Knowledge Base: False      Query: False
#
# To Evaluate: ( not False or  not True or True) and ( not False and True) and False
# Knowledge Base: False      Query: True
#
# To Evaluate: ( not True or  not True or False) and ( not True and True) and True
# Knowledge Base: False      Query: False
#
# To Evaluate: ( not True or  not True or True) and ( not True and True) and True
# Knowledge Base: False      Query: True
#
# Knowledge Base entailing the query

# %% [markdown]
# # Create your own senarios and test them

# %%
kb_rule = input('Enter the KB_rule: ')
# (PvQ)^(~RvP)
query = input('Enter the query: ')
# R

to_check_entailment(kb_rule, query)
# Out:
# Enter the KB_rule: (PvQ)^(~RvP)
# Enter the query: R
# To Evaluate: (False or False) and ( not False or False)
# Knowledge Base: False      Query: False
#
# To Evaluate: (False or False) and ( not True or False)
# Knowledge Base: False      Query: True
#
# To Evaluate: (False or True) and ( not False or False)
# Knowledge Base: True      Query: False
#
# To Evaluate: (False or True) and ( not True or False)
# Knowledge Base: False      Query: True
#
# To Evaluate: (True or False) and ( not False or True)
# Knowledge Base: True      Query: False
#
# To Evaluate: (True or False) and ( not True or True)
# Knowledge Base: True      Query: True
#
# To Evaluate: (True or True) and ( not False or True)
# Knowledge Base: True      Query: False
#
# To Evaluate: (True or True) and ( not True or True)
# Knowledge Base: True      Query: True
#
# Knowledge Base entailing the query
